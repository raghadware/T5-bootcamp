# %% [markdown]
# # Rain Prediction - Australia New

# %% [markdown]
# ### Context
# - Predict next-day rain by training classification models on the target variable RainTomorrow.
#
# ### Content
# - This dataset contains about 10 years of daily weather observations from many locations across Australia.
#
# #### RainTomorrow is the target variable to predict. It means -- did it rain the next day, Yes or No? This column is Yes if the rain for that day was 1mm or more.

# %% [markdown]
# #### - imports necessary libraries such as NumPy, Pandas, Matplotlib, Seaborn, ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### - Read the csv file

# %%
weather = pd.read_csv('weatherAUS.csv')

# %%
weather
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# #### Preprocessing
#
# - Data Cleaning
# > - Change column labels
# > - `Rain_Today` and `Rain_Tomorrow` oneHotEncoder
# > - Fill numerical values with mean or median using imputer
# > - convert data into numbers using OrdinalEncoder
# > - Get Correlation matrix and plot heatmap
# > - Change `Date` column into Datetime type
#
#
# - shuffle data
# - handling nan
# - drop unnecessary columns ['Rainfall' , 'Sunshine' , 'Evaporation']
# - split to train and test data

# %% [markdown]
# #### EDA

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
weather.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
weather['WindGustDir'].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', nan, 'ENE',
#        'SSE', 'S', 'NW', 'SE', 'ESE', 'E', 'SSW'], dtype=object)

# %%
weather[weather['WindGustDir'].isna() == True][['WindGustDir','WindDir9am','WindDir3pm']]
# Out:
#        WindGustDir WindDir9am WindDir3pm
# 14             NaN          S        WNW
# 64             NaN          N        NaN
# 65             NaN        NaN        NaN
# 283            NaN          E        WNW
# 435            NaN        ENE         SW
# ...            ...        ...        ...
# 145091         NaN        NaN        NaN
# 145092         NaN          W        NaN
# 145316         NaN        ESE          E
# 145335         NaN        ENE         SW
# 145459         NaN        ESE        ESE
#
# [10326 rows x 3 columns]

# %% [markdown]
# #### - Drop unnecessary columns ['Rainfall' , 'Sunshine' , 'Evaporation']

# %%
columns_to_drop = ['Rainfall', 'Sunshine', 'Evaporation']
weather = weather.drop(columns_to_drop, axis=1)

# %% [markdown]
# #### - Forward fill missing values

# %%
weather = weather.fillna(method='ffill')
weather = weather.fillna(method='bfill')

# %%
weather['Date'] = pd.to_datetime(weather['Date'])

# %%
weather.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm',
#        'RainToday', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# #### - Replace the values in the 'RainToday' column.

# %%
weather['RainToday'] = weather['RainToday'].replace('Yes',1)
weather['RainToday'] = weather['RainToday'].replace('No',0)

# %% [markdown]
# #### - Replace the values in the 'RainTomorrow' column.

# %%
weather['RainTomorrow'] = weather['RainTomorrow'].replace('Yes',1)
weather['RainTomorrow'] = weather['RainTomorrow'].replace('No',0)

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  datetime64[ns]
#  1   Location       145460 non-null  object
#  2   MinTemp        145460 non-null  float64
#  3   MaxTemp        145460 non-null  float64
#  4   WindGustDir    145460 non-null  object
#  5   WindGustSpeed  145460 non-null  float64
#  6   WindDir9am     145460 non-null  object
#  7   WindDir3pm     145460 non-null  object
#  8   WindSpeed9am   145460 non-null  float64
#  9   WindSpeed3pm   145460 non-null  float64
#  10  Humidity9am    145460 non-null  float64
#  11  Humidity3pm    145460 non-null  float64
#  12  Pressure9am    145460 non-null  float64
#  13  Pressure3pm    145460 non-null  float64
#  14  Cloud9am       145460 non-null  float64
#  15  Cloud3pm       145460 non-null  float64
# ...

# %%
weather.isna().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %% [markdown]
# #### - Convert data into numbers using LabelEncoder

# %%
le = preprocessing.LabelEncoder()

weather['Location'] = le.fit_transform(weather['Location'])
weather['WindDir9am'] = le.fit_transform(weather['WindDir9am'])
weather['WindDir3pm'] = le.fit_transform(weather['WindDir3pm'])
weather['WindGustDir'] = le.fit_transform(weather['WindGustDir'])

weather.sample(10)
# Out:
#              Date  Location  MinTemp  MaxTemp  WindGustDir  WindGustSpeed  \
# 48598  2016-04-27         9      2.2     23.6            7           35.0
# 93954  2010-10-06        39     23.6     30.5            1           43.0
# 66184  2014-09-14        19      4.7     19.6           10           31.0
# 49018  2017-06-21         9     -2.4     14.7           15           15.0
# 13953  2014-05-30        21     10.4     26.3            5           33.0
# 53218  2012-03-01        23      8.3     14.8           13           67.0
# 41673  2015-02-03        45     18.6     25.9           10           44.0
# 103057 2010-05-20        28      8.0     17.5            9           13.0
# 7036   2011-10-15        10     13.2     29.1           15           39.0
# 24934  2011-02-16        30     18.5     27.5            5           19.0
#
#         WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Cloud9am  \
# 48598            7           6           6.0          24.0  ...       8.0
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  datetime64[ns]
#  1   Location       145460 non-null  int32
#  2   MinTemp        145460 non-null  float64
#  3   MaxTemp        145460 non-null  float64
#  4   WindGustDir    145460 non-null  int32
#  5   WindGustSpeed  145460 non-null  float64
#  6   WindDir9am     145460 non-null  int32
#  7   WindDir3pm     145460 non-null  int32
#  8   WindSpeed9am   145460 non-null  float64
#  9   WindSpeed3pm   145460 non-null  float64
#  10  Humidity9am    145460 non-null  float64
#  11  Humidity3pm    145460 non-null  float64
#  12  Pressure9am    145460 non-null  float64
#  13  Pressure3pm    145460 non-null  float64
#  14  Cloud9am       145460 non-null  float64
#  15  Cloud3pm       145460 non-null  float64
# ...

# %% [markdown]
# #### Histogram plots

# %%
weather.hist(bins=50, figsize=(20,15));

# %% [markdown]
# #### Heat map

# %%
# corr = weather.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot=True, fmt='.2f',  vmin=-1 , vmax=1)
plt.show()

# %% [markdown]
# ### Separating the year, month, day and hour values and storing each in a separate column

# %%
weather['Year'] = weather['Date'].dt.year
weather['Month'] = weather['Date'].dt.month
weather['Day'] = weather['Date'].dt.day

# %% [markdown]
# ### Definition of functions to convert month to season

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'autumn'

# %% [markdown]
# ### Apply the function on the month column and create the season column

# %%
weather['Season'] = weather['Month'].apply(get_season)

# %% [markdown]
# ### Count Season

# %%
###count Season
season = sns.countplot(x ='Season',data = weather , palette = 'Set2')
season.bar_label(season.containers[0]) 
plt.title('Season count', fontsize=18)
plt.show()

# %% [markdown]
# ### Count RainToday

# %%
rain_counts = weather['RainToday'].value_counts()
labels = ['Rain', 'Not Rain']
colors = ['lightblue', 'gray']

plt.pie(rain_counts, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('RainToday Distribution', fontsize=18)
plt.axis('equal')
plt.show()

# %% [markdown]
# #### Modeling - Predciting rain

# %%
weather
# Out:
#              Date  Location  MinTemp  MaxTemp  WindGustDir  WindGustSpeed  \
# 0      2008-12-01         2     13.4     22.9           13           44.0
# 1      2008-12-02         2      7.4     25.1           14           44.0
# 2      2008-12-03         2     12.9     25.7           15           46.0
# 3      2008-12-04         2      9.2     28.0            4           24.0
# 4      2008-12-05         2     17.5     32.3           13           41.0
# ...           ...       ...      ...      ...          ...            ...
# 145455 2017-06-21        41      2.8     23.4            0           31.0
# 145456 2017-06-22        41      3.6     25.3            6           22.0
# 145457 2017-06-23        41      5.4     26.9            3           37.0
# 145458 2017-06-24        41      7.8     27.0            9           28.0
# 145459 2017-06-25        41     14.9     27.0            9           28.0
#
#         WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Cloud9am  \
# ...

# %% [markdown]
# #### - Drop Date, Year, Month, Day and Season columns

# %%
weather = weather.drop(['Date', 'Year', 'Month', 'Day', 'Season'], axis = 1)

# %%
weather
# Out:
#         Location  MinTemp  MaxTemp  WindGustDir  WindGustSpeed  WindDir9am  \
# 0              2     13.4     22.9           13           44.0          13
# 1              2      7.4     25.1           14           44.0           6
# 2              2     12.9     25.7           15           46.0          13
# 3              2      9.2     28.0            4           24.0           9
# 4              2     17.5     32.3           13           41.0           1
# ...          ...      ...      ...          ...            ...         ...
# 145455        41      2.8     23.4            0           31.0           9
# 145456        41      3.6     25.3            6           22.0           9
# 145457        41      5.4     26.9            3           37.0           9
# 145458        41      7.8     27.0            9           28.0          10
# 145459        41     14.9     27.0            9           28.0           2
#
# ...

# %%
X = weather.drop('RainTomorrow' , axis = 1)

# %%
y = weather['RainTomorrow']

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y  , test_size = 0.2)
X_train , X_val , y_train , y_val = train_test_split(X_train , y_train  , test_size = 0.2)

# %% [markdown]
# ### Random Forest Classifier

# %%
ran = RandomForestClassifier(n_estimators = 150, random_state = 0, max_depth = 10)  
ran.fit(X_train, y_train) 
y_pred = ran.predict(X_train)

# %%
accuracy_score(y_train, y_pred)
# Out:
# 0.8665005263497111

# %%
y_pred = ran.predict(X_val)

# %%
accuracy_score(y_val, y_pred)
# Out:
# 0.8489301366331529

# %% [markdown]
# ### Decision Tree Classifier

# %%
des = DecisionTreeClassifier(max_depth = 8)  
des.fit(X_train, y_train) 
y_pred = des.predict(X_train)

# %%
accuracy_score(y_train, y_pred)
# Out:
# 0.8474230347820483

# %%
y_pred = ran.predict(X_val)

# %%
accuracy_score(y_val, y_pred)
# Out:
# 0.8489301366331529

# %% [markdown]
# ### Logistic Regression Model

# %%
log = LogisticRegression(max_iter=1000)
log.fit(X_train, y_train) 
y_pred = log.predict(X_train)

# %%
accuracy_score(y_train, y_pred)
# Out:
# 0.8361870797258685

# %%
y_pred = ran.predict(X_val)

# %%
accuracy_score(y_val, y_pred)
# Out:
# 0.8489301366331529

# %% [markdown]
# ### KNeighbors Classifier

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_train)

# %%
accuracy_score(y_train, y_pred)
# Out:
# 0.8773712591574108

# %%
y_pred = ran.predict(X_val)

# %%
accuracy_score(y_val, y_pred)
# Out:
# 0.8489301366331529
