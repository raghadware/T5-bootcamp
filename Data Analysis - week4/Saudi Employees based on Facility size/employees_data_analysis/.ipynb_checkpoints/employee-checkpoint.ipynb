# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r'employees-arabic-new.csv')

# %%
df
# Out:
#       السنة  الربع            المنطقة  \
# 0      2023      1    المنطقة الشرقية
# 1      2023      1    المنطقة الشرقية
# 2      2023      1    المنطقة الشرقية
# 3      2023      1    المنطقة الشرقية
# 4      2023      1       منطقة الباحة
# ...     ...    ...                ...
# 2756   2023      1  منطقة مكة المكرمة
# 2757   2023      1  منطقة مكة المكرمة
# 2758   2023      1  منطقة مكة المكرمة
# 2759   2023      1        منطقة نجران
# 2760   2023      1        منطقة نجران
#
#                                        النشاط الاقتصادي    حجم المنشأة  \
# 0     وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...          صغيرة
# 1     وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...          كبيرة
# 2     وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...  متناهية الصغر
# 3     وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...         متوسطة
# 4     وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...  متناهية الصغر
# ...                                                 ...            ...
# ...

# %%
df.shape
# Out:
# (2761, 12)

# %%
df.head(10)
# Out:
#    السنة  الربع                المنطقة  \
# 0   2023      1        المنطقة الشرقية
# 1   2023      1        المنطقة الشرقية
# 2   2023      1        المنطقة الشرقية
# 3   2023      1        المنطقة الشرقية
# 4   2023      1           منطقة الباحة
# 5   2023      1            منطقة الجوف
# 6   2023      1            منطقة الجوف
# 7   2023      1  منطقة الحدود الشمالية
# 8   2023      1  منطقة الحدود الشمالية
# 9   2023      1           منطقة الرياض
#
#                                     النشاط الاقتصادي    حجم المنشأة  \
# 0  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...          صغيرة
# 1  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...          كبيرة
# 2  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...  متناهية الصغر
# 3  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...         متوسطة
# 4  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...  متناهية الصغر
# 5  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...          صغيرة
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2761 entries, 0 to 2760
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   السنة                   2761 non-null   int64
#  1   الربع                   2761 non-null   int64
#  2   المنطقة                 2761 non-null   object
#  3   النشاط الاقتصادي        2761 non-null   object
#  4   حجم المنشأة             2761 non-null   object
#  5   عدد المنشآت             2761 non-null   int64
#  6   عدد العاملين السعوديين  2761 non-null   int64
#  7   عدد السعوديين (ذكور)    2761 non-null   int64
#  8   عدد السعوديات (إناث)    2761 non-null   int64
#  9   عدد العاملين الأجانب    2761 non-null   int64
#  10  عدد الأجانب (ذكور)      2761 non-null   int64
#  11  عدد الأجنبيات (إناث)    2761 non-null   int64
# dtypes: int64(9), object(3)
# memory usage: 259.0+ KB

# %%
df.isnull().sum()
# Out:
# السنة                     0
# الربع                     0
# المنطقة                   0
# النشاط الاقتصادي          0
# حجم المنشأة               0
# عدد المنشآت               0
# عدد العاملين السعوديين    0
# عدد السعوديين (ذكور)      0
# عدد السعوديات (إناث)      0
# عدد العاملين الأجانب      0
# عدد الأجانب (ذكور)        0
# عدد الأجنبيات (إناث)      0
# dtype: int64

# %%
sales_df.describe()
# Out:
#         السنة   الربع    عدد المنشآت  عدد العاملين السعوديين  \
# count  2761.0  2761.0    2761.000000             2761.000000
# mean   2023.0     1.0     434.568272              809.024267
# std       0.0     0.0    3141.656144             2984.337731
# min    2023.0     1.0       1.000000                0.000000
# 25%    2023.0     1.0       3.000000               12.000000
# 50%    2023.0     1.0      15.000000               69.000000
# 75%    2023.0     1.0      88.000000              370.000000
# max    2023.0     1.0  107429.000000            66311.000000
#
#        عدد السعوديين (ذكور)  عدد السعوديات (إناث)  عدد العاملين الأجانب  \
# count           2761.000000           2761.000000            2761.00000
# mean             486.466498            322.557769            2788.79464
# std             2100.759424           1150.146681           12895.53561
# min                0.000000              0.000000               0.00000
# ...

# %%
df.tail()
# Out:
#       السنة  الربع            المنطقة النشاط الاقتصادي    حجم المنشأة  \
# 2756   2023      1  منطقة مكة المكرمة         غير معرف          صغيرة
# 2757   2023      1  منطقة مكة المكرمة         غير معرف  متناهية الصغر
# 2758   2023      1  منطقة مكة المكرمة         غير معرف         متوسطة
# 2759   2023      1        منطقة نجران         غير معرف          صغيرة
# 2760   2023      1        منطقة نجران         غير معرف  متناهية الصغر
#
#       عدد المنشآت  عدد العاملين السعوديين  عدد السعوديين (ذكور)  \
# 2756          411                     747                   382
# 2757        15906                    2160                  1150
# 2758            8                     225                   129
# 2759           46                      59                    23
# 2760         3306                     239                   131
#
#       عدد السعوديات (إناث)  عدد العاملين الأجانب  عدد الأجانب (ذكور)  \
# 2756                   365                  3415                3331
# ...

# %%
#sales_df["النشاط الاقتصادي"].replace('صنع', "الصناعات")
 
# creating a filter for age column
# where age = "Twenty five"
#filter = sales_df["The economic activity"]=="صنع"
 
# printing only filtered columns
#sales_df.where(filter).dropna()
#sales_df.head(90)
#sales_df['النشاط الاقتصادي'].str.replace(r'صنع', 'صناعات', regex=True)

#sales_df['النشاط الاقتصادي'].str.replace(r'(\sصتع)', 'صناعات', regex=True).to_list

df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'صُنع.+', 'صناعات', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'صناعة.+', 'صناعات', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'تجارة.+', 'تجارة', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'الخدمات.+', 'خدمات', regex=True)

# %%
#after edit

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*خدمات.*', 'الخدمات', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*صُنع.*', 'الصناعات', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*صنع.*', 'الصناعات', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*صناعة.*', 'الصناعات', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*تجارة.*', 'التجارة', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*للنقل.*', 'النقل', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*النقل.*', 'النقل', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*إقامة.*', 'الإقامة', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*المكاتب.*', 'أنشطة المكاتب ', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*للمكاتب.*', 'أنشطة المكاتب ', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*البرمجة.*', 'البرمجة ', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*تعدين.*', 'التعدين ', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*للتعدين.*', 'التعدين ', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*تشييد.*', 'الأنشطة المعمارية والهندسية ', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*المعمارية.*', 'الأنشطة المعمارية والهندسية ', regex=True)

# %%
df['النشاط الاقتصادي']=df['النشاط الاقتصادي'].str.replace(r'.*الهندسة.*', 'الأنشطة المعمارية والهندسية ', regex=True)

# %%
df['النشاط الاقتصادي'].nunique()
# Out:
# 41

# %%
df['النشاط الاقتصادي'].unique()
# Out:
# array(['الخدمات', 'صيد الأسماك وتربية المائيات', 'الصناعات',
#        'توصيل الكهرباء والغاز والبخار وتكييف الهواء',
#        'تمويل التأمين وإعادة التأمين وصناديق المعاشات التقاعدية باستثناء الضمان الاجتماعي الإلزامي',
#        'التعدين ', 'الأنشطة المعمارية والهندسية ',
#        'تجميع المياه ومعالجتها وتوصيلها', 'التجارة',
#        'أنشطة جمع النفايات ومعالجتها وتصريفها ، واسترجاع المواد',
#        'أنشطة النشر', 'أنشطة المنظمات ذات العضوية',
#        'أنشطة المكتبات والمحفوظات والمتاحف والأنشطة الثقافية الأخرى',
#        'أنشطة المكاتب ', 'الإقامة',
#        'أنشطة البريد ونقل الرسائل والطرود بواسطة مندوبين', 'البرمجة ',
#        'أنشطة الأمن والتحقيقات',
#        'أنشطة الاسر المعيشية التي تستخدم أفراداً للعمل المنزلي',
#        'أنشطة الاستخدام', 'النقل',
#        'الطباعة واستنساخ وسائط الأعلام المسجّلة', 'الصرف الصحي',
#        'الصحة البشرية', 'الحراجة وقطع الأخشاب', 'التعليم',
#        'البحث والتطوير في المجال العلمي',
#        'الأنشطة المهنية والعلمية والتقنية الأخرى',
# ...
